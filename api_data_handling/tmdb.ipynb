# %%
import numpy as np
import pandas as pd

# %%
import requests

url = f"https://api.themoviedb.org/3/movie/top_rated?api_key=ce66a9f468ee38efd796fdc9326e26f3&language=en-US&page=1"

response = requests.get(url)
data = response.json()

# %%
movies = data['results']

# %%
df = pd.DataFrame(movies)

# %%
df
# Out:
#     adult                     backdrop_path        genre_ids       id  \
# 0   False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         [18, 80]      278
# 1   False  /tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg         [18, 80]      238
# 2   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg         [18, 80]      240
# 3   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg  [18, 36, 10752]      424
# 4   False  /w4bTBXcqXc2TUyS5Fc4h67uWbPn.jpg             [18]      389
# 5   False  /xyWKrni8WrYzqn7ztvI5nIY0h62.jpg      [35, 10749]  1181678
# 6   False  /ukfI9QkU1aIhOhKXYWE9n3z1mFR.jpg  [16, 10751, 14]      129
# 7   False  /cfT29Im5VDvjE0RpyKOSdCKZal7.jpg     [28, 80, 53]      155
# 8   False  /6N5d02quKqMKqvTpOdFmBDy9scY.jpg  [35, 18, 10749]    19404
# 9   False  /b6HWTOxn1xevvyHU2K9ICvaRU6g.jpg     [14, 18, 80]      497
# 10  False  /2u7zbn8EudG6kLlBzUYqP8RyFU4.jpg     [12, 14, 28]      122
# 11  False  /hiKmpZMGZsrkA3cdce8a7Dpos1j.jpg     [35, 53, 18]   496243
# ...

# %%
df.head(2)
# Out:
#    adult                     backdrop_path genre_ids   id original_language  \
# 0  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg  [18, 80]  278                en
# 1  False  /tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg  [18, 80]  238                en
#
#              original_title  \
# 0  The Shawshank Redemption
# 1             The Godfather
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     49.7673
# 1  Spanning the years 1945 to 1955, a chronicle o...     37.4539
#
#                         poster_path release_date                     title  \
# 0  /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23  The Shawshank Redemption
# 1  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14             The Godfather
#
#    video  vote_average  vote_count
# 0  False         8.717       30002
# 1  False         8.700       22666

# %%
df.shape
# Out:
# (20, 14)

# %%
df = df[['title', 'release_date', 'popularity', 'vote_average']]
df.head()
# Out:
#                       title release_date  popularity  vote_average
# 0  The Shawshank Redemption   1994-09-23     49.7673         8.717
# 1             The Godfather   1972-03-14     37.4539         8.700
# 2     The Godfather Part II   1974-12-20     25.9014         8.573
# 3          Schindler's List   1993-12-15     23.7128         8.567
# 4              12 Angry Men   1957-04-10     20.1853         8.556

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,201):
    url = f"https://api.themoviedb.org/3/movie/top_rated?api_key=ce66a9f468ee38efd796fdc9326e26f3&language=en-US&page={i}"
    response = requests.get(url)
    data = pd.DataFrame(response.json()['results'])
    df = pd.concat([df, data], ignore_index=True)

# %%
df
# Out:
#       adult                     backdrop_path                   genre_ids  \
# 0     False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg                    [18, 80]
# 1     False  /tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg                    [18, 80]
# 2     False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg                    [18, 80]
# 3     False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg             [18, 36, 10752]
# 4     False  /w4bTBXcqXc2TUyS5Fc4h67uWbPn.jpg                        [18]
# ...     ...                               ...                         ...
# 3995  False  /kz8uFk8AYDu4an8PhkdGLbVJXMi.jpg  [53, 28, 35, 80, 18, 9648]
# 3996  False  /c31SAQjVMeVGv7mZsrw5BKGXj2P.jpg               [16, 14, 878]
# 3997  False  /sAiTihJ8bjEqg8nYUIlTQUnVXuj.jpg                    [37, 12]
# 3998  False  /hExTiLbfB93HwEwkeQxb3q4nHtQ.jpg                 [18, 10749]
# 3999  False  /yXybBEC45p84D0Ky7GmQQYrclVr.jpg                [28, 12, 14]
#
#           id original_language             original_title  \
# ...

# %%
df = df[['title','original_language','release_date', 'popularity', 'vote_average']]
df
# Out:
#                           title original_language release_date  popularity  \
# 0      The Shawshank Redemption                en   1994-09-23     49.7673
# 1                 The Godfather                en   1972-03-14     37.4539
# 2         The Godfather Part II                en   1974-12-20     25.9014
# 3              Schindler's List                en   1993-12-15     23.7128
# 4                  12 Angry Men                en   1957-04-10     20.1853
# ...                         ...               ...          ...         ...
# 3995                   Thursday                en   1998-09-25      2.6244
# 3996                   Steamboy                ja   2004-07-17      3.6157
# 3997                    Hidalgo                en   2004-02-04      4.5559
# 3998        Last Tango in Paris                it   1972-12-15      3.9237
# 3999  Pokémon Detective Pikachu                en   2019-05-03      7.4109
#
#       vote_average
# 0            8.717
# 1            8.700
# ...

# %%
df.to_csv("top_rated_movies.csv", index=False)
